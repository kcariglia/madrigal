# %% [markdown]
# ## Test of Madrigal HAPI server

# %%
# necessary imports
from hapiclient import hapi
from hapiplot import hapiplot
#import madtest_config
import os, os.path
import datetime
import traceback

# %%
server = "http://192.52.65.29:9000/hapi"

# %%
server2 = "https://cdaweb.gsfc.nasa.gov/hapi"

# %%
# test dataset 0 - what is an empty response supposed to look like?
dataset = "TIMED_EDP_GUVI" # TIMED 
start = "2020-05-10T00:00Z"
stop = "2020-05-14T00:00Z"
parameters = ''

# %%
data, meta = hapi(server2, dataset, parameters, start, stop)

# %%
data

# %%
# test dataset 1 - 
dataset = "8310_17561" # McMurdo fluxgate magnetometer
start = "2022-05-10T00:00Z"
stop = "2022-05-14T00:00Z"
parameters = ''

# %%
# test dataset 2 - 
dataset = "8260_1060" # DASI-VA Magnetometer
start = "2020-06-29T00:00Z"
stop = "2020-07-01T00:00Z"
parameters = ''

# %%
# test dataset 3 - 
dataset = "8261_1060" # DASI-ATLAS Magnetometer
start = "2023-05-01T00:00Z"
stop = "2023-05-14T00:00Z"
parameters = ''

# %%
# test dataset 4 - 
dataset = "8262_1060" # DASI-AUGUSTA Magnetometer
start = "2022-05-01T00:00Z"
stop = "2022-05-14T00:00Z"
parameters = ''

# %%
# test dataset 5 - 
dataset = "8263_1060" # DASI-BLUESKY Magnetometer
start = "2021-05-01T00:00Z"
stop = "2021-05-14T00:00Z"
parameters = ''

# %%
# test dataset 6 - 
dataset = "8264_1060" # DASI-BOULDER Magnetometer
start = "2022-05-01T00:00Z"
stop = "2022-05-14T00:00Z"
parameters = ''

# %%
# test dataset 7 - 
dataset = "8265_1060" # DASI-HAYSTACK Magnetometer
start = "2021-05-01T00:00Z"
stop = "2021-05-14T00:00Z"
parameters = ''

# %%
# test dataset 8 - 
dataset = "8266_1060" # DASI-HENNEPIN Magnetometer
start = "2021-05-01T00:00Z"
stop = "2021-05-14T00:00Z"
parameters = ''

# %%
# test dataset 9 - 
dataset = "8267_1060" # DASI-MISSOURI Magnetometer
start = "2021-05-01T00:00Z"
stop = "2021-05-14T00:00Z"
parameters = ''

# %%
# test dataset 10 - 
dataset = "8268_1060" # DASI-NEWBRITAIN Magnetometer
start = "2021-05-01T00:00Z"
stop = "2021-05-14T00:00Z"
parameters = ''

# %%
# test dataset 11 - 
dataset = "8269_1060" # DASI-ODESSA Magnetometer
start = "2023-05-01T00:00Z"
stop = "2023-05-14T00:00Z"
parameters = ''

# %%
# test dataset 12 - 
dataset = "8270_1060" # DASI-PAWNEE Magnetometer
start = "2022-05-01T00:00Z"
stop = "2022-05-14T00:00Z"
parameters = ''

# %%
# test dataset 13 - 
dataset = "8271_1060" # DASI-SUGARHILLS Magnetometer
start = "2021-05-01T00:00Z"
stop = "2021-05-14T00:00Z"
parameters = ''

# %%
# test dataset 14 - 
dataset = "8300_4101" # Sodankyla Magnetometer, SGO Magnetometers - XYZ - 1 min
start = "2003-05-01T00:00Z"
stop = "2003-05-14T00:00Z"
parameters = ''

# %%
# test dataset 15 - 
dataset = "8309_17560" # south pole fluxgate magnetometer
start = "2022-05-10T00:00Z"
stop = "2022-05-14T00:00Z"
parameters = ''

# %%
# test dataset 16 - 
dataset = "8305_17575" # south pole searchcoil magnetometer
start = "2025-06-10T00:00Z"
stop = "2025-06-14T00:00Z"
parameters = ''

# %%
# test dataset x - NOT WORKING ATM
dataset = "8250_1700" # Jicamarca magnetometers
start = "2010-05-01T00:00Z"
stop = "2010-05-14T00:00Z"
parameters = ''

# %%
data, meta = hapi(server, dataset, parameters, start, stop)

# %%
data
# Out:
# array([(b'2022-05-12T00:00:00.000Z', 2432.165, -1824.7  , 3077.54 ),
#        (b'2022-05-12T00:00:01.000Z', 2430.64 , -1827.755, 3079.07 ),
#        (b'2022-05-12T00:00:02.000Z', 2427.585, -1832.33 , 3079.07 ), ...,
#        (b'2022-05-10T23:59:57.000Z', 1376.865,  -997.045, 1719.505),
#        (b'2022-05-10T23:59:58.000Z', 1376.865,  -998.57 , 1724.08 ),
#        (b'2022-05-10T23:59:59.000Z', 1375.34 , -1001.62 , 1721.03 )],
#       shape=(345376,), dtype=[('Time', 'S24'), ('BN_NT', '<f8'), ('BE_NT', '<f8'), ('BD_NT', '<f8')])

# %%
meta
# Out:
# {'HAPI': '3.3',
#  'status': {'code': 1200, 'message': 'OK'},
#  'startDate': '2000-04-19T00:00:00',
#  'stopDate': '2025-03-30T23:59:00',
#  'parameters': [{'name': 'Time',
#    'type': 'isotime',
#    'units': 'UTC',
#    'fill': None,
#    'length': 24},
#   {'name': 'BN_NT',
#    'type': 'double',
#    'units': 'nT',
#    'fill': 'NaN',
#    'description': 'Geodetic Northward component of geomagnetic field in nT'},
#   {'name': 'BE_NT',
#    'type': 'double',
#    'units': 'nT',
#    'fill': 'NaN',
#    'description': 'Geodetic Eastward component of geomagnetic field in nT'},
#   {'name': 'BD_NT',
#    'type': 'double',
#    'units': 'nT',
#    'fill': 'NaN',
#    'description': 'Geodetic Downward component of geomagnetic field in nT'}],
#  'geoLocation': [166.7, -77.9, 0.01],
#  'contact': 'Allan Weatherwax',
#  'contactID': 'wxwax@mit.edu',
#  'x_server': 'http://192.52.65.29:9000/hapi',
#  'x_dataset': '8310_17561',
#  'x_parameters': '',
#  'x_time.min': '2022-05-10T00:00Z',
# ...

# %%
hapiplot(data, meta)
# Out:
# {'HAPI': '3.3',
#  'status': {'code': 1200, 'message': 'OK'},
#  'startDate': '2000-04-19T00:00:00',
#  'stopDate': '2025-03-30T23:59:00',
#  'parameters': [{'name': 'Time',
#    'type': 'isotime',
#    'units': 'UTC',
#    'fill': None,
#    'length': 24},
#   {'name': 'BN_NT',
#    'type': 'double',
#    'units': 'nT',
#    'fill': 'NaN',
#    'description': 'Geodetic Northward component of geomagnetic field in nT',
#    'hapiplot': {'figure': <Figure size 1008x432 with 1 Axes>}},
#   {'name': 'BE_NT',
#    'type': 'double',
#    'units': 'nT',
#    'fill': 'NaN',
#    'description': 'Geodetic Eastward component of geomagnetic field in nT',
#    'hapiplot': {'figure': <Figure size 1008x432 with 1 Axes>}},
#   {'name': 'BD_NT',
#    'type': 'double',
#    'units': 'nT',
#    'fill': 'NaN',
#    'description': 'Geodetic Downward component of geomagnetic field in nT',
#    'hapiplot': {'figure': <Figure size 1008x432 with 1 Axes>}}],
#  'geoLocation': [166.7, -77.9, 0.01],
# ...
